# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
datos = pd.read_csv("prueba.csv", index_col="ID")
datos.head(10)
# Out:
#                                      Series_Title  \
# ID
# 1                        The Shawshank Redemption
# 2                                   The Godfather
# 3                                 The Dark Knight
# 4                          The Godfather: Part II
# 5                                    12 Angry Men
# 6   The Lord of the Rings: The Return of the King
# 7                                    Pulp Fiction
# 8                                Schindler's List
# 9                                       Inception
# 10                                     Fight Club
#
#                                           Poster_Link Released_Year  \
# ID
# 1   https://m.media-amazon.com/images/M/MV5BMDFkYT...          1994
# 2   https://m.media-amazon.com/images/M/MV5BM2MyNj...          1972
# 3   https://m.media-amazon.com/images/M/MV5BMTMxNT...          2008
# 4   https://m.media-amazon.com/images/M/MV5BMWMwMG...          1974
# ...

# %%
datos.isnull().any()
# Out:
# Series_Title     False
# Poster_Link      False
# Released_Year    False
# Certificate       True
# Runtime          False
# Genre            False
# IMDB_Rating      False
# Overview         False
# Meta_score        True
# Director         False
# Star1            False
# Star2            False
# Star3            False
# Star4            False
# No_of_Votes      False
# Gross             True
# dtype: bool

# %% [markdown]
# Mostrar la cantidad de filas nulas de las columnas ‘Certificate’ y
# ‘Meta_score’

# %%
nulos_certificates = datos['Certificate'].isnull().sum()
nulos_meta_score = datos['Meta_score'].isnull().sum()

print("Filas nulas en Certificate:", nulos_certificates)
print("Filas nulas en Meta_score:", nulos_meta_score)
# Out:
# Filas nulas en Certificate: 101
# Filas nulas en Meta_score: 157

# %% [markdown]
# Eliminar las filas nulas de las columnas anteriormente
# nombradas

# %%
df_eliminar  = datos.dropna(subset=['Certificate', 'Meta_score'])

# %% [markdown]
# Aplicar un filtro utilizando una función que muestre solamente las películas del
# género de Guerra (War) y que se genere un nuevo dataframe con las columnas: ID,
# Series_Title, IMDB_Rating y Meta_score. Guardar este nuevo dataset con la función correspondiente

# %%
prueba= datos.to_csv("C:\\Users\\conys\\Documents\\VsCode\\Prueba\\datasinnulos.csv")
